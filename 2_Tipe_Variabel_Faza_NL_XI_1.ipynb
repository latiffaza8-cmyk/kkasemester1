# %% [markdown]
# <a href="https://colab.research.google.com/github/latiffaza8-cmyk/kkasemester1/blob/main/2_Tipe_Variabel_Faza_NL_XI_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Menampilkan Teks Bebas

# %%
print("Halo dunia")
# Out:
# Halo dunia

# %%
print("selamat datang di phyton")
# Out:
# selamat datang di phyton

# %%
print("Mohammad Faza Nurdiansyah Latif")
# Out:
# Mohammad Faza Nurdiansyah Latif

# %% [markdown]
# #Variabel

# %%
BB = 51
print(BB)
# Out:
# 51

# %%
umur = 16
print(umur)
# Out:
# 16

# %%
nama = "Mohammad Faza Nurdiansyah Latif"
print(nama)
# Out:
# Mohammad Faza Nurdiansyah Latif

# %% [markdown]
# #Menampilkan Variabel dan Teks Bebas

# %%
print(f"umur saya {umur} tahun")
# Out:
# umur saya 16 tahun

# %%
print("halo", nama)
# Out:
# halo Mohammad Faza Nurdiansyah Latif

# %%
telurint("Hargatelurhargaharga_telur = 26000
prtelurhargaHarga telurtelur per 1 kg adalah", harga_telur)
# Out:
# Harga telur per 1 kg adalah 26000

# %%
harga_telur = 26000
print("Harga telur per 1 kg adalah " + str(harga_telur))
# Out:
# Harga telur per 1 kg adalah 26000

# %%
nama_pembeli = "Rafael"
print("Nama pembeli telur adalah"  + nama_pembeli)
# Out:
# Nama pembeli telur adalahRafael

# %% [markdown]
# #Escape Character

# %%
print("Nama: Mohammad Faza Nurdiansyah Latif ")
print("Kelas: XI.1")
print("Nomor absen: 26")
# Out:
# Nama: Mohammad Faza Nurdiansyah Latif
# Kelas: XI.1
# Nomor absen: 26

# %%
print("Nama\t\t: Mohammad Faza Nurdiansyah Latif\nKelas\t\t: XI.1\nNomor absen\t: 26")
# Out:
# Nama		: Mohammad Faza Nurdiansyah Latif
# Kelas		: XI.1
# Nomor absen	: 26

# %%
print("""Nama: Mohammad Faza Nurdiansyah Latif
Kelas: XI.1
Nomor absen:26""")
# Out:
# Nama: Mohammad Faza Nurdiansyah Latif
# Kelas: XI.1
# Nomor absen:26

# %%
print('ja\'far shodiq')
# Out:
# ja'far shodiq

# %%
print("ja'far shodiq")
# Out:
# ja'far shodiq

# %%
print("Bu Shinta berkata, \"Semua harus menyimak pelajaran.\"")
# Out:
# Bu Shinta berkata, "Semua harus menyimak pelajaran."

# %%
print('Bu Shinta berkata, "Semua harus menyimak pelajaran."')
# Out:
# Bu Shinta berkata, "Semua harus menyimak pelajaran."

# %%
print("lokasi file video karnaval ada di D:\\Karnaval 2025\\mp4")
# Out:
# lokasi file video karnaval ada di D:\Karnaval 2025\mp4

# %% [markdown]
# #Parameter Fungsi print

# %%
tahun = 2009
bulan = "Juli"
tanggal = 21

print(tanggal)
print(bulan)
print(tahun)
# Out:
# 21
# Juli
# 2009

# %%
tahun = 2009
bulan = "Juli"
tanggal = 21

print(tanggal, end=" ")
print(bulan, end=" ")
print(tahun)
# Out:
# 21 Juli 2009

# %%
tahun = 2009
bulan = "Juli"
tanggal = 21

print(tanggal, bulan, tahun, sep="/")
# Out:
# 21/Juli/2009

# %% [markdown]
# #Latihan:
#
# Tanggal-Bulan-Tahun

# %%
nama_depan = "Mohammad"
nama_belakang = "Latif"

print(nama_depan, nama_belakang)
# Out:
# Mohammad Latif

# %%
nama_depan = "Mohammad"
nama_belakang = "Latif"

print(nama_depan, end=" ")
print(nama_belakang, end=" ")
# Out:
# Mohammad Latif

# %% [markdown]
# #Soal latihan Pemrograman Python

# %%
print('Bu Shinta berkata, "berikut adalah judul pelajaran hari senin selasa rabu silakan disimpan di laptop masing-masing di folder local disk D:\\Jadwal Pelajaran\\Kelas XI Semester I."\n')
print("Jadwal Pelajaran Mingguan")
print("===============================")
print("Jam\tsenin\t\tselasa\t\trabu")
print("Jam 1\tMatematika\tBahasa\t\tInformatika")
print("Jam 2\tBahasa Ing.\tSejarah\t\tMa\'rifatullah")
print("Jam 3\tInformatika\tOlahraga\tBiologi")
# Out:
# Bu Shinta berkata, "berikut adalah judul pelajaran hari senin selasa rabu silakan disimpan di laptop masing-masing di folder local disk D:\Jadwal Pelajaran\Kelas XI Semester I."
#
# Jadwal Pelajaran Mingguan
# ...
# Jam	senin		selasa		rabu
# Jam 1	Matematika	Bahasa		Informatika
# Jam 2	Bahasa Ing.	Sejarah		Ma'rifatullah
# Jam 3	Informatika	Olahraga	Biologi

# %% [markdown]
# Latihan soal
#
# 1. Tampilkan teks bebas:Hari ini saya bahagia belajar bahasa phyton
# 2.Tampilkan nilai variabel:mata_pelajaran_favorit = Kode dan Kecerdasan Buatan
# 3.Tampilkan nilai variabel:nilai_kka = 100
# 4.Tampilkan teks bebas dan nilai variabel dengan  tiga metode(f string, "+",","):"Nilai KKA saya adalah {nilai_kka} loh!"

# %% [markdown]
# #Jawaban dari soal di atas

# %%
print("Hari ini saya bahagia belajar bahasa phyton")
# Out:
# Hari ini saya bahagia belajar bahasa phyton

# %%
mata_pelajaran_favorit = "Kode dan Kecerdasan Buatan"
print(mata_pelajaran_favorit)
# Out:
# Kode dan Kecerdasan Buatan

# %%
nilai_kka = 100
print(nilai_kka)
# Out:
# 100

# %%
nilai_kka = 100
print(f"Nilai KKA saya adalah {nilai_kka} loh!")
# Out:
# Nilai KKA saya adalah 100 loh!

# %%
nilai_kka = 100
print("Nilai KKA saya adalah",nilai_kka, "loh!")
# Out:
# Nilai KKA saya adalah 100 loh!

# %%
nilai_kka = 100
print("Nilai KKA saya adalah " + str(nilai_kka) + " loh!")
# Out:
# Nilai KKA saya adalah 100 loh!

# %% [markdown]
# #Parameter Fungsi

# %%
nama_hama_1 = "Naufal"
nama_hama_2 = "Favian"
nama_hama_3 = "Humaira"

print(nama_hama_1, nama_hama_2, nama_hama_3, nama_hama_2,  sep="~")
# Out:
# Naufal~Favian~Humaira~Favian

# %%
nama_hama_1 = "Naufal"
nama_hama_2 = "Favian"
nama_hama_3 = "Humaira"
print(nama_hama_2, end="~")
print(nama_hama_1)
print(nama_hama_3, end="~")
print(nama_hama_1)
# Out:
# Favian~Naufal
# Humaira~Naufal

# %% [markdown]
# #Assignment

# %% [markdown]
# #Single Assignment

# %%
nama_siswa_2 = "Farel"
nama_siswa_3 = "Dhapne"

print(nama_siswa_2)
print(nama_siswa_3)
# Out:
# Farel
# Dhapne

# %% [markdown]
# #Multiple Assignment

# %%
nama_siswa_4, nama_siswa_5 = "Sada", "Selo"

print(nama_siswa_4)
print(nama_siswa_5)
# Out:
# Sada
# Selo

# %% [markdown]
# #Assign ke banyak Variabel sekaligus

# %%
nilai_afa = nilai_favian = 100

print(nilai_afa)
print(nilai_favian)
# Out:
# 100
# 100

# %% [markdown]
# #Perubahan nilai variabel

# %%
nilai_afa = 40

print(nilai_afa)
# Out:
# 40

# %% [markdown]
# #Latihan Soal: Harga barang di swalayan

# %% [markdown]
# #Single Assignment

# %%
Susu = "Rp15.000"
Roti = "Rp12.000"
Telur = 24000

print(Susu)
print(Roti)
print(Telur)
# Out:
# Rp15.000
# Rp12.000
# 24000

# %%
Gula, Minyak = "Rp14.000", 20000

print(Gula)
print(Minyak)
# Out:
# Rp14.000
# 20000

# %%
Mie_ayam = Mie_soto = Mie_kari = "Rp3.500"

print(Mie_ayam)
print(Mie_soto)
print(Mie_kari)
# Out:
# Rp3.500
# Rp3.500
# Rp3.500

# %%
Susu, Roti = Roti, Susu

print(Susu)
print(Roti)
# Out:
# Rp12.000
# Rp15.000

# %%
Telur -=2000
Minyak +=3000

print(Telur)
print(Minyak)
# Out:
# 22000
# 23000

# %% [markdown]
# #Aritmatika

# %%
print("5000*3")
# Out:
# 5000*3

# %%
#Operand tanpa disimpan dalam variabel
print(5000*3)
# Out:
# 15000

# %%
#simpan operand ke dalam variabel
harga_kojek = 6000
banyak_porsi = 3

print(harga_kojek*banyak_porsi)
# Out:
# 18000

# %%
#simpan hasil operasi ke dalam variabel
total_harga_kojek = 3000*3

print(total_harga_kojek)
# Out:
# 9000

# %%
#simpan nilai operand dan hasil operasi ke dalam variabel
harga_cilok = 10000
jumlah_porsi_cilok = 5
harga_total_cilok = harga_cilok*jumlah_porsi_cilok

print(harga_total_cilok)
# Out:
# 50000

# %%
uang_yang_diterima = 100000
uang_kembalian = uang_yang_diterima - harga_total_cilok

print(uang_kembalian)
# Out:
# 50000

# %% [markdown]
# #Soal

# %%
#operand tanpa disimpan dalam variabel

print(24*3)
# Out:
# 72

# %%
#simpan hasil operasi ke dalam variabel
total_jumlah_botol = 24*3

print(total_jumlah_botol)
# Out:
# 72

# %%
banyak_botol_per_kardus = 24
jumlah_kardus = 3

print(banyak_botol_per_kardus*jumlah_kardus)
# Out:
# 72

# %%
banyak_botol_per_kardus = 24
jumlah_kardus = 3
total_jumlah_botol = banyak_botol_per_kardus*jumlah_kardus

print(total_jumlah_botol)
# Out:
# 72

# %% [markdown]
# #Tipe Variabel

# %%
usia = 65

type(usia)
# Out:
# int

# %%
berat_telur = 2.5

type(berat_telur)
# Out:
# float

# %%
nama = "Apon"

type(nama)
# Out:
# str

# %%
remidi = False

type(remidi)
# Out:
# bool

# %%
remidi = True

type(remidi)
# Out:
# bool

# %%
koordinat_bintang = -1.5

type(koordinat_bintang)
# Out:
# float

# %%
koordinat_titik = -8
type(koordinat_titik)
# Out:
# int

# %% [markdown]
# #Input

# %%
panjang = 10
lebar = 5
luas = panjang*lebar

print(luas)
# Out:
# 50

# %%
input()
# Out:
# 10
# '10'

# %%
panjang = input()
# Out:
# 10

# %%
print(panjang)
# Out:
# 10

# %%
lebar = input ()
# Out:
# 5

# %%
print(lebar)
# Out:
# 5

# %%
luas = panjang*lebar
print(luas)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1308584410.py in <cell line: 0>()
# ----> 1 luas = panjang*lebar
#       2 print(luas)
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
type(panjang)
# Out:
# str

# %%
type(lebar)
# Out:
# str

# %%
panjang = int(panjang)

# %%
lebar = int(lebar)

# %%
type(panjang)
# Out:
# int

# %%
panjang_1 = int(input("Masukkan panjang persegi: "))
# Out:
# Masukkan panjang persegi: 10

# %%
panjang_2 = int(input("Masukkan panjang persegi: "))
lebar_2 = int(input("Masukkan lebar persegi: "))

luas_2 = panjang_2*lebar_2

print(f"Luas persegi panjang adalah {luas_2} cm^2")
# Out:
# Masukkan panjang persegi: 4
# Masukkan lebar persegi: 10
# Luas persegi panjang adalah 40 cm^2

# %% [markdown]
# #Latihan Soal

# %%
panjang_balok = int(input("Masukkan panjang balok: "))
lebar_balok = int(input("Masukkan lebar balok: "))
tinggi_balok = int(input("Masukkan tinggi balok: "))

volume_balok = panjang_balok*lebar_balok*tinggi_balok

print(f"Volume balok adalah {volume_balok} cm^3")
# Out:
# Masukkan panjang balok: 10
# Masukkan lebar balok: 5
# Masukkan tinggi balok: 4
# Volume balok adalah 200 cm^3

# %% [markdown]
# #Operator Perbandingan

# %%
print(8<5)
# Out:
# False

# %%
print(8>5)
# Out:
# True

# %%
print(9>=9)
# Out:
# True

# %%
print(8==5)
# Out:
# False

# %%
print(8==8)
# Out:
# True

# %%
print(1 !=1)
# Out:
# False

# %%
a = 10
b = 20
c = 30

print(a>c)
# Out:
# False

# %%
print(a>30)
# Out:
# False

# %%
nilai_kka = 75
kkm_kka = 80

print(nilai_kka > kkm_kka)
# Out:
# False

# %% [markdown]
# #Operator Logika

# %%
print(8>7 and 5>6)
# Out:
# False

# %%
print(8>7 and 5<6)
# Out:
# True

# %%
print(8>7 or 5>6)
# Out:
# True

# %%
print(not(8>7 or 5>6))
# Out:
# False

# %%
print(not (8>=9 or 9!=8))
# Out:
# False

# %%
iq_min = 125
tinggi_min = 165

print(125  >=iq_min and 170 >= tinggi_min)
# Out:
# True

# %%
iq_afa = 125
tinggi_afa = 170

print(iq_afa >= iq_min and tinggi_afa >= tinggi_min)
# Out:
# True

# %% [markdown]
# #Soal

# %%
tinggi_min = 165
berat_badan_min = 50
maks_umur = 25
tinggi_farel = 170
berat_badan_farel = 55
umur_farel = 23
print(tinggi_min <= tinggi_farel and berat_badan_min <= berat_badan_farel and maks_umur >= umur_farel)
# Out:
# True
